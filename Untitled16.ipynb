# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
import plotly.graph_objects as go
import plotly.express as px
import plotly
import os

# %%
df_20 = pd.read_csv("/content/players_21.csv")

# %%
Data Preprocessing & Feature Engineering

# %%
df_20 = df_20.drop(['sofifa_id', 'player_url', 'long_name', 'body_type', 'real_face', 'nation_position', 'nation_jersey_number'], axis=1)

# %%
1: Position Columns

# %%
stats = ['ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram',
       'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb',
       'lcb', 'cb', 'rcb', 'rb']
for col in stats:
    new = df_20[col].str.split("+", n = 1, expand = True)
    df_20[col] = new[0]
# Replace NaN with 0
df_20[stats] = df_20[stats].fillna(0)
df_20[stats] = df_20[stats].astype(int)

# %%
2: Player's Work Rate

# %%
df_20 = pd.concat([df_20, pd.get_dummies(df_20['work_rate'])], axis=1)
# Drop original work_rate column
df_20 = df_20.drop(['work_rate'], axis=1)

# %%
3: Player's DOB

# %%
# Split the dob column to fetch month
new = df_20["dob"].str.split("-", n = 2, expand = True)
df_20["birth_month"] = new[1].astype(int)

# %%
4: Player's Position

# %%
df_20 = pd.concat([df_20, df_20['player_positions'].str.get_dummies(sep=', ').add_prefix('Position_')], axis=1)
# Drop original work_rate column
df_20 = df_20.drop(['player_positions'], axis=1)

# %%
BMI: New feature creation

# %%
df_20['bmi'] = df_20['weight_kg'] / (df_20['height_cm']/100)**2

# %%
 Missing Value Estimation

# %%
# Check the missing values in the column
missing_data = df_20.isnull().sum().sort_values(ascending=False)
missing_data = missing_data.reset_index(drop=False)
missing_data = missing_data.rename(columns={"index": "Columns", 0: "Value"})
missing_data['Proportion'] = (missing_data['Value']/len(df_20))*100
import plotly.express as px

# Assuming missing_data is your DataFrame with columns 'Columns' and 'Proportion'

# Filter data for columns with proportion > 10
sample = missing_data[missing_data['Proportion'] > 10]

# Create a bar chart
fig = px.bar(sample, x='Columns', y='Proportion',
             color='Proportion',
             color_continuous_scale=px.colors.sequential.Viridis_r,
             title='Percentage of Missing values in Columns',
             labels={'Proportion': 'Percentage'})

# Customize layout
fig.update_layout(paper_bgcolor='rgba(255,255,255,0.8)',
                  plot_bgcolor='rgba(255,255,255,0.8)',
                  font=dict(family='Cambria, monospace', size=12, color='#000000'))

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="96907b5e-562f-4bfe-acf9-6581e20fbe5e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("96907b5e-562f-4bfe-acf9-6581e20fbe5e")) {                    Plotly.newPlot(                        "96907b5e-562f-4bfe-acf9-6581e20fbe5e",                        [{"alignmentgroup":"True","hovertemplate":"Columns=%{x}\u003cbr\u003ePercentage=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[100.0,95.9987331081081,92.56756756756756,89.00443412162163,89.00443412162163,89.00443412162163,89.00443412162163,89.00443412162163,89.00443412162163,56.10747466216216,10.995565878378379,10.995565878378379,10.995565878378379,10.995565878378379,10.995565878378379,10.995565878378379],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["defending_marking","loaned_from","player_tags","gk_positioning","gk_speed","gk_reflexes","gk_kicking","gk_handling","gk_diving","player_traits","dribbling","passing","shooting","pace","physic","defending"],"xaxis":"x","y":[100.0,95.9987331081081,92.56756756756756,89.00443412162163,89.00443412162163,89.00443412162163,89.00443412162163,89.00443412162163,89.00443412162163,56.10747466216216,10.995565878378379,10.995565878378379,10.995565878378379,10.995565878378379,10.995565878378379,10.995565878378379],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555 ...

# %%
Fill Missing Values

# %%
# Fill missing values of these columns by median
cols = ["dribbling", "defending", "physic", "passing", "shooting", "pace"]
for col in cols:
    df_20[col] = df_20[col].fillna(df_20[col].median())
df_20 = df_20.fillna(0)

# %%
Exploratory Data Analysis

# %%
Scatter Plot (colored by Age) year 2020 - Overall Rating vs Value in Euros

# %%
import plotly.express as px

fig = px.scatter(df_20, x='overall', y='value_eur',
                 color='age', size='age',
                 color_continuous_scale='Plasma',
                 title='Styled Scatter Plot (colored by Age) year 2020 - Overall Rating vs Value in Euros',
                 labels={'overall': 'Overall Rating', 'value_eur': 'Value in Euros'},
                 hover_data=['short_name'])

fig.update_layout(paper_bgcolor='rgba(255,255,255,0.8)',
                  plot_bgcolor='rgba(255,255,255,0.8)',
                  font=dict(family='Cambria, monospace', size=12, color='#000000'))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="49080f0d-2438-40ef-bd2b-d195db5a5152" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("49080f0d-2438-40ef-bd2b-d195db5a5152")) {                    Plotly.newPlot(                        "49080f0d-2438-40ef-bd2b-d195db5a5152",                        [{"customdata":[["L. Messi"],["Cristiano Ronaldo"],["J. Oblak"],["R. Lewandowski"],["Neymar Jr"],["K. De Bruyne"],["K. Mbapp\u00e9"],["M. ter Stegen"],["V. van Dijk"],["Alisson"],["S. Man\u00e9"],["M. Salah"],["T. Courtois"],["S. Ag\u00fcero"],["Sergio Ramos"],["K. Benzema"],["M. Neuer"],["Casemiro"],["Ederson"],["R. Sterling"],["J. Kimmich"],["H. Kane"],["P. Dybala"],["S. Handanovi\u010d"],["T. Kroos"],["E. Hazard"],["K. Koulibaly"],["N. Kant\u00e9"],["J. Sancho"],["T. Alexander-Arnold"],["Bruno Fernandes"],["A. Laporte"],["Fabinho"],["A. Robertson"],["Bernardo Silva"],["G. Chiellini"],["H. Lloris"],["L. Su\u00e1rez"],["L. Modri\u0107"],["A. Di Mar\u00eda"],["W. Szcz\u0119sny"],["P. Aubameyang"],["Sergio Busquets"],["C. Immobile"],["K. Navas"],["A. Griezmann"],["H. Son"],["Roberto Firmino"],["R. Varane"],["P. Pogba"],["M. Verratti"],["A. G\u00f3mez"],["Piqu\u00e9"],["David Silva"],["Y. Sommer"],["M. Hummels"],["J. Henderson"],["Jordi Alba"],["T. M\u00fcller"],["De Gea"],["Carvajal"],["J. Vardy"],["K. Havertz"],["G. Donnarumma"],["M. de Ligt"],["M. Rashford"],["L. San\u00e9"],["F. de Jong"],["Marquinhos"],["C. Lenglet"],["S. Milinkovi\u0107-Savi\u0107"],["M. \u0160kriniar"],["M. Depay"],["T. Werner"],["Rodri"],["B. Leno"],["S. Gnabry"],["Ricardo Pereira"],["R. Lukaku"],["Luis Alberto"],["M. Icardi"],["H. Ziyech"],["Thiago Silva"],["D. Mertens"],["M. Pjani\u0107"],["G. Wijnaldum"],["D. God\u00edn"],["T. Alderweireld"],["L. Bonucci"],["P. Gul\u00e1csi"],["M. Reus"],["K. Walker"],["Thiago"],["Parejo"],["C. Eriksen"],["Alex Sandro"],["Koke"],["L. Insigne"],["R. Mahrez"],["E. Haaland"],["L. Mart\u00ednez"],["Oyarzabal"],["N. S\u00fcle"],["Arthur"],["L. Goretzka"],["Grimaldo"],["A. Martial"],["J. Brandt"],["K. Coman"],["J. Gim\u00e9nez"],["A. Onana"],["W. Ndidi"],["Sa\u00fal"],["R. B\u00fcrki"],["S. de Vrij"],["L. Digne"],["R. Guerreiro"],["T. Partey"],["Alex Telles"],["M. Brozovi\u0107"],["Fernandinho"],["Jes\u00fas Navas"],["K. Schmeichel"],["S. Sirigu"],["Lucas Leiva"],["A. Witsel"],["Rui Patr\u00edcio"],["Azpilicueta"],["Douglas Costa"],["Iago Aspas"],["J. Corona"],["I. Gueye"],["D. Alaba"],["Isco"],["Pizzi"],["W. Ben Yedder"],["J. Ili\u010di\u0107"],["R. Jim\u00e9nez"],["Felipe"],["N. Tagliafico"],["F. Valverde"],["M. \u00d8degaard"],["O. Demb\u00e9l\u00e9"],["Gay\u00e0"],["T. Strakosha"],["Pau L\u00f3pez"],["J. Gomez"],["S. Bergwijn"],["F. Mendy"],["A. Wan-Bissaka"],["A. Hakimi"],["A. Romagnoli"],["D. Alli"],["D. van de Beek"],["D. Zakaria"],["Gabriel Jesus"],["S. Umtiti"],["M. Kova\u010di\u0107"],["Jo\u00e3o Cancelo"],["N\u00e9lson Semedo"],["K. Casteels"],["A. Lopes"],["M. Sabitzer"],["Diego Carlos"],["K. Manolas"],["J. Matip"],["Juan Bernat"],["N. Fekir"],["Z. Ibrahimovi\u0107"],["Jo\u00e3o Moutinho"],["S. Mandanda"],["G. Higua\u00edn"],["Renato Augusto"],["C. Vela"],["B. Matuidi"],["J. Vertonghen"],["G. Bale"],["Marcelo"],["R. Nainggolan"],["E. Banega"],["E. D\u017eeko"],["A. Vidal"],["Yuri Berchiche"],["Fernando"],["K. Trippier"],["I. G\u00fcndo\u011fan"],["Paulinho"],["Oscar"],["K. Trapp"],["Coutinho"],["Muniain"],["L. Hr\u00e1deck\u00fd"],["A. Lacazette"],["Aitor"],["W. Zaha"],["C. Ar\u00e1nguiz"],["D. Tadi\u0107"],["Sergi Roberto"],["F. Acerbi"],["Allan"],["Lucas Moura"],["T. Hazard"],["Portu"],["Jorginho"],["E. Vi\u0161\u0107a"],["Gerard Moreno"],["F. Kosti\u0107"],["D. Zapata"],["Rafa"],["M. D\u00fabravka"],["M. Acu\u00f1a"],["Ronaldo Cabrais"],["Reguil\u00f3n"],[" ...

# %%
Scatter Plot - Nationality vs Overall

# %%
import plotly.graph_objs as go
import plotly.offline as pyo

# Assuming 'df_20' is your DataFrame for the year 2020

fig = go.Figure()

sample = df_20.sort_values(by='nationality')

fig.add_trace(go.Bar(
    x=sample['nationality'],
    y=sample['overall'],
    marker=dict(
        color=sample['overall'],
        colorscale='Viridis',
        showscale=True
    ),
    text=sample['short_name']
))

fig.update_layout(title='Styled Bar Chart - Nationality vs Overall',
                  xaxis_title='Nationality',
                  yaxis_title='Overall Rating',
                  paper_bgcolor='rgba(255,255,255,0.8)',
                  plot_bgcolor='rgba(255,255,255,0.8)',
                  font=dict(family='Cambria, monospace', size=12, color='#000000'))

pyo.iplot(fig, filename="Nationality_vs_Overall")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="
73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,72,72,72,72,72,72,73,72,72,73,72,72,72,72,72,72,73,72,73,72,72,72,72,72,72,72,72,72,73,72,72,72,72,72,72,72,72,72,73,73,72,72,72,72,72,72,72,75,74,70,69,75,69,69,69,75,69,69,69,69,69,69,69,69,69,69,69,69,75,75,75,75,69,75,75,75,75,69,69,69,69,69,75,69,69,75,69,75,69,75,69,75,69,75,69,69,75,68,63,75,68,75,75,75,68,75,68,68,75,75,75,68,68,68,68,68,68,68,75,75,69,69,69,69,68,68,75,68,69,68,68,68,68,68,68,68,68,68,68,75,70,69,75,70,70,70,74,70,70,70,70,70,70,70,70,70,70,70,70,70,74,74,70,74,70,70,70,70,70,70,70,70,74,74,70,70,70,70,70,70,70,70,70,74,74,70,70,70,70,69,69,69,69,69,69,69,69,69,69,69,69,75,75,69,75,69,69,69,69,74,74,69,70,70,70,70,74,74,74,74,74,75,70,70,70,70,69,69,69,69,69,69,70,78,73,62,62,62,86,79,62,60,60,60,55,62,59,62,80,62,59,60,59,57,59,59,60,59,81,60,62,60,82,53,52,60,60,60,62,59,63,58,55,80,60,57,61,88,62,62,81,79,58,61,58,81,79,62,58,60,81,59,56,63,60,60,52,63,60,58,56,79,63,56,62,62,52,59,60,84,57,56,57,80,62,57,87,57,62,60,60,57,59,82,62,62,57,59,59,59,59,60,60,62,60,62,57,80,62,59,61,59,57,60,78,62,79,60,60,59,52,60,60,59,83,59,78,60,62,60,62,62,59,81,60,62,60,62,79,60,60,59,62,62,59,62,61,61,61,61,58,80,54,58,78,79,57,82,56,58,61,58,53,58,79,61,78,56,56,57,56,60,63,63,61,61,79,57,57,61,58,58,61,54,61,82,54,54,58,55,57,58,60,58,61,61,78,61,78,78,61,58,61,58,61,62,57,57,57,63,61,58,61,61,58,78,63,56,63,61,78,60,62,82,63,58,58,63,58,53,55,62,62,58,58,63,58,61,60,89,61,83,57,61,58,83,61,61,57,58,58,63,56,56,61,61,58,84,60,63,56,53,79,61,85,59,60,61,63,55,60,61,80,66,74,66,68,55,68,68,65,68,71,60,80,65,68,68,52,62,62,62,68,65,60,55,72,65,65,65,70,65,61,61,61,55,66,61,67,66,67,61,67,67,61,66,67,67,67,53,54,54,66,54,73,72,72,76,53,53,53,61,66,67,61,67,72,55,67,55,55,65,62,62,72,60,62,60,55,65,65 ...

# %%
Box Plot (with Suspected Outliers) - Overall Rating vs BMI

# %%
import plotly.graph_objs as go
import plotly.offline as pyo

# Assuming 'df_20' is your DataFrame for the year 2020

fig = go.Figure()

sample = df_20.sort_values(by='overall')

fig.add_trace(go.Box(
    x=sample['overall'],
    y=sample['bmi'],
    name="Suspected Outliers",
    boxpoints='all',  # show all points
    jitter=0.3,  # add jitter for better visibility of points
    pointpos=-1.8,  # adjust position of points
    marker=dict(
        size=8,
        color='rgba(31, 119, 180, 0.7)',
        outliercolor='rgba(255, 0, 0, 0.6)',
        line=dict(
            outliercolor='rgba(255, 0, 0, 0.6)',
            outlierwidth=2)),
    line_color='rgba(255, 255, 255, 0.3)',
    text=sample['short_name']
))

fig.update_layout(title='Styled Box Plot (with All Points) - Overall Rating vs BMI',
                  xaxis_title='Overall Rating',
                  yaxis_title='BMI',
                  paper_bgcolor='rgba(255,255,255,0.8)',
                  plot_bgcolor='rgba(255,255,255,0.8)',
                  font=dict(family='Cambria, monospace', size=12, color='#000000'),
                  xaxis_rangeslider_visible=True)

pyo.iplot(fig, filename="Box_Plot_Overall_vs_BMI")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id
. Hidalgo","K. Scales","D. Neil","L. Isherwood","D. Kruse","J. Bagan","R. Hillier","D. Boyle","N. Jones","S. Czajor","L. Hasani","R. Law","K. Sad\u0142ocha","G. Yow","N. De Queiroz","M. Cox","K. Swaleh","S. Pineau","S. Guarirapa","K. Munro","A. Zaharia","M. Hals\u00f8y","A. Stawiarz","J. Campa\u00f1a","C. Johnston","E. Johnston","A. Cano","C. Barks","C. Widell","N. Henchoz","W. Shepherd","E. Bilen","J. Sirois","H. Hopper","A. Pietrogiovanna","J. Ondrejka","A. Mej\u00eda","T. Onyeka","S. Pop","J. Lee","H. Kendrick","S. Al Saeed","D. La Torre","J. Young","C. Mu\u00f1oz","Cui Lin","S. Callan","J. Neal","R. Galvin","Lee Seung Jae","G. Al Enazi","J. Honohan","H. Al Quraish","D. Power","Yang Yu min","J. Gonz\u00e1lez","D. Kalinowski","A. Al Enazi","A. Al Dheyabi","J. Devers","Gao Dalun","N. O'Keeffe","G. Garner","S. Lynch","P. Metcalfe","O. Maritu","Deng Jiaxing","D. Retamal","Huang Zihao","Pan Ximing","Teng Shangkun","A. Foley","W. Aouachria","F. Jakobsson","Xie Zhiwei","T. Al Shahrani","Zhou Baizhao","J. Wright","H. Boyes","J. Belehouan","C. Coulter","L. Schellenberg","Lee Sung Yoon","J. Starbuck","J. Osaghae","B. McManus","A. Vogler","N. Solskj\u00e6r","M. Harri ...

# %%
Proportion of Player's per Position¶

# %%
attack = ['RW', 'LW', 'ST', 'CF', 'LS', 'RS', 'RF', 'LF']
sample = df_20.query('team_position in @attack')
fig = px.pie(sample, names='team_position',
             color_discrete_sequence=px.colors.sequential.Plasma_r,
             title='Percentage of players in Attacker Role')
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.update_layout(paper_bgcolor='rgba(0,0,0,0)',
                  plot_bgcolor='rgba(0,0,0,0)',
                  font=dict(family='Cambria, monospace', size=12, color='#000000'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b89b1340-39c7-44fd-939b-dac6a3bc5512" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b89b1340-39c7-44fd-939b-dac6a3bc5512")) {                    Plotly.newPlot(                        "b89b1340-39c7-44fd-939b-dac6a3bc5512",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"team_position=%{label}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["LS","ST","LW","LS","LW","RW","CF","LW","ST","RS","LW","RS","RW","LW","RS","ST","CF","LF","ST","RS","ST","RS","RS","ST","LW","RW","LS","LS","LW","ST","ST","ST","RF","ST","RW","ST","ST","ST","ST","ST","ST","LS","ST","RW","RS","ST","RW","RW","RS","LW","LW","ST","RW","RW","LW","LS","LW","LS","RW","LS","RW","LS","ST","LS","LS","RW","RW","LS","RW","ST","ST","ST","RW","LS","LW","LS","RW","ST","LW","ST","LS","ST","ST","LW","ST","RW","RF","RS","LS","RW","ST","LW","LW","ST","LF","LS","ST","ST","LS","RW","ST","ST","RS","ST","RS","ST","ST","LS","LW","LS","ST","ST","RW","LS","LS","RS","ST","ST","RW","RS","ST","RW","RS","LS","RW","LS","RS","LS","LS","LS","LW","RS","ST","LS","LW","ST","LS","LW","RS","ST","RS","ST","ST","RS","ST","ST","RS","RW","ST","ST","LW","RW","LS","LW","LW","LW